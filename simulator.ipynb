# %%
import os
import requests as req

os.environ['NO_PROXY'] = '127.0.0.1'

# %%
#for var in range(10):

resp = req.get("http://127.0.0.1:8888/index.html")
resp = req.get("http://127.0.0.1:8888/1.jgp")
resp = req.get("http://127.0.0.1:8888/2.jgp")
resp = req.get("http://127.0.0.1:8888/3.jgp")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/matheus/Documents/Faculdade/Redes/TrabalhoPratico/ServidorHTTP/simulator.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/matheus/Documents/Faculdade/Redes/TrabalhoPratico/ServidorHTTP/simulator.ipynb#ch0000001?line=0'>1</a> #for var in range(10):
# ----> <a href='vscode-notebook-cell:/home/matheus/Documents/Faculdade/Redes/TrabalhoPratico/ServidorHTTP/simulator.ipynb#ch0000001?line=2'>3</a> resp = req.get("http://127.0.0.1:8888/index.html")
#       <a href='vscode-notebook-cell:/home/matheus/Documents/Faculdade/Redes/TrabalhoPratico/ServidorHTTP/simulator.ipynb#ch0000001?line=3'>4</a> resp = req.get("http://127.0.0.1:8888/1.jgp")
# ...

# %%
resp = req.get("http://127.0.0.1:8888/1.jgp")
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
resp = req.get("http://127.0.0.1:8888/2.jgp")

# %%
resp = req.get("http://127.0.0.1:8888/3.jgp")
